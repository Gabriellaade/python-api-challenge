# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 568

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        weather_response = requests.get(city_url)
        city_weather = weather_response.json()


        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]


        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port-aux-francais
# Processing Record 2 of Set 1 | anibare
# City not found. Skipping...
# Processing Record 3 of Set 1 | whitehorse
# Processing Record 4 of Set 1 | ocean pointe
# City not found. Skipping...
# Processing Record 5 of Set 1 | grytviken
# Processing Record 6 of Set 1 | recani
# Processing Record 7 of Set 1 | lazaro cardenas
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | blackmans bay
# Processing Record 10 of Set 1 | saint-pierre
# Processing Record 11 of Set 1 | papatowai
# Processing Record 12 of Set 1 | edinburgh of the seven seas
# Processing Record 13 of Set 1 | mantsala
# Processing Record 14 of Set 1 | hamilton
# Processing Record 15 of Set 1 | baltinava
# Processing Record 16 of Set 1 | portland
# Processing Record 17 of Set 1 | fort st. john
# Processing Record 18 of Set 1 | adamstown
# Processing Record 19 of Set 1 | klyuchi
# Processing Record 20 of Set 1 | thompson
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | zangguy
# City not found. Skipping...
# Processing Record 23 of Set 1 | fannuj
# City not found. Skipping...
# Processing Record 24 of Set 1 | weno
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | quellon
# Processing Record 27 of Set 1 | kupang
# Processing Record 28 of Set 1 | iqaluit
# Processing Record 29 of Set 1 | haiku-pauwela
# Processing Record 30 of Set 1 | rosarito
# Processing Record 31 of Set 1 | bilibino
# Processing Record 32 of Set 1 | bada
# Processing Record 33 of Set 1 | namibe
# Processing Record 34 of Set 1 | port alfred
# Processing Record 35 of Set 1 | amursk
# Processing Record 36 of Set 1 | yoichi
# Processing Record 37 of Set 1 | isafjordur
# Processing Record 38 of Set 1 | kil
# Processing Record 39 of Set 1 | waitangi
# Processing Record 40 of Set 1 | palikir - national government center
# Processing Record 41 of Set 1 | timimoun
# Processing Record 42 of Set 1 | vila velha
# Processing Record 43 of Set 1 | ponta delgada
# Processing Record 44 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 45 of Set 1 | likasi
# Processing Record 46 of Set 1 | traverse city
# Processing Record 47 of Set 1 | bethel
# Processing Record 48 of Set 1 | saint-francois
# Processing Record 49 of Set 1 | puerto natales
# Processing Record 50 of Set 1 | east end
# Processing Record 0 of Set 2 | san antonio de pale
# Processing Record 1 of Set 2 | albany
# Processing Record 2 of Set 2 | tabou
# Processing Record 3 of Set 2 | college
# Processing Record 4 of Set 2 | dudinka
# Processing Record 5 of Set 2 | kenai
# Processing Record 6 of Set 2 | maintirano
# Processing Record 7 of Set 2 | corn island
# Processing Record 8 of Set 2 | mossel bay
# Processing Record 9 of Set 2 | tranovaho
# City not found. Skipping...
# Processing Record 10 of Set 2 | zhangjiakou
# Processing Record 11 of Set 2 | qaqortoq
# Processing Record 12 of Set 2 | ararat
# Processing Record 13 of Set 2 | margaret river
# Processing Record 14 of Set 2 | bredasdorp
# Processing Record 15 of Set 2 | palangkaraya
# Processing Record 16 of Set 2 | eirunepe
# Processing Record 17 of Set 2 | puerto ayora
# Processing Record 18 of Set 2 | boa vista
# Processing Record 19 of Set 2 | mhamid
# Processing Record 20 of Set 2 | banff
# Processing Record 21 of Set 2 | kiffa
# Processing Record 22 of Set 2 | onguday
# Processing Record 23 of Set 2 | tsiombe
# Processing Record 24 of Set 2 | jamestown
# Processing Record 25 of Set 2 | charters towers
# Processing Record 26 of Set 2 | tiksi
# Processing Record 27 of Set 2 | luganville
# Processing Record 28 of Set 2 | chilca
# Processing Record 29 of Set 2 | malvan
# Processing Record 30 of Set 2 | georgetown
# Processing Record 31 of Set 2 | stanley
# Processing Record 32 of Set 2 | kittila
# Processing Record 33 of Set 2 | naifaru
# Processing Record 34 of Set 2 | port elizabeth
# Processing Record 35 of Set 2 | el porvenir
# Processing Record 36 of Set 2 | happy valley-goose bay
# Processing Record 37 of Set 2 | nicoya
# Processing Record 38 of Set 2 | gadzhiyevo
# Processing Record 39 of Set 2 | hithadhoo
# Processing Record 40 of Set 2 | anadyr
# Processing Record 41 of Set 2 | hawaiian paradise park
# Processing Record 42 of Set 2 | punta arenas
# Processing Record 43 of Set 2 | kurmuk
# Processing Record 44 of Set 2 | fale old settlement
# Processing Record 45 of Set 2 | motueka
# Processing Record 46 of Set 2 | wuwei
# Processing Record 47 of Set 2 | nguigmi
# Processing Record 48 of Set 2 | ilulissat
# Processing Record 49 of Set 2 | lodja
# Processing Record 0 of Set 3 | visby
# Processing Record 1 of Set 3 | okhotsk
# Processing Record 2 of Set 3 | tra vinh
# Processing Record 3 of Set 3 | ola
# Processing Record 4 of Set 3 | ciudad bolivar
# Processing Record 5 of Set 3 | taman rajawali
# City not found. Skipping...
# Processing Record 6 of Set 3 | pisco
# Processing Record 7 of Set 3 | gamay
# Processing Record 8 of Set 3 | sitka
# Processing Record 9 of Set 3 | vredendal
# Processing Record 10 of Set 3 | alice springs
# Processing Record 11 of Set 3 | udachny
# Processing Record 12 of Set 3 | zemio
# Processing Record 13 of Set 3 | ruidoso
# Processing Record 14 of Set 3 | zheleznodorozhnyy
# Processing Record 15 of Set 3 | port lincoln
# Processing Record 16 of Set 3 | west island
# Processing Record 17 of Set 3 | kulhudhuffushi
# Processing Record 18 of Set 3 | bongouanou
# Processing Record 19 of Set 3 | enewetak
# Processing Record 20 of Set 3 | lys'va
# Processing Record 21 of Set 3 | olonkinbyen
# Processing Record 22 of Set 3 | toliara
# Processing Record 23 of Set 3 | hasaki
# Processing Record 24 of Set 3 | naryn
# Processing Record 25 of Set 3 | okola
# Processing Record 26 of Set 3 | agbabu
# Processing Record 27 of Set 3 | al hasaheisa
# Processing Record 28 of Set 3 | avarua
# Processing Record 29 of Set 3 | sinabang
# Processing Record 30 of Set 3 | springbok
# Processing Record 31 of Set 3 | pangody
# Processing Record 32 of Set 3 | lata
# Processing Record 33 of Set 3 | sorong
# Processing Record 34 of Set 3 | yelizovo
# Processing Record 35 of Set 3 | lebu
# Processing Record 36 of Set 3 | leibnitz
# Processing Record 37 of Set 3 | al bawiti
# Processing Record 38 of Set 3 | tughyl
# Processing Record 39 of Set 3 | ribeira grande
# Processing Record 40 of Set 3 | zambezi
# Processing Record 41 of Set 3 | iskateley
# Processing Record 42 of Set 3 | port mathurin
# Processing Record 43 of Set 3 | aykhal
# Processing Record 44 of Set 3 | shimoda
# Processing Record 45 of Set 3 | mugia
# Processing Record 46 of Set 3 | longyearbyen
# Processing Record 47 of Set 3 | ha
# City not found. Skipping...
# Processing Record 48 of Set 3 | coquimbo
# Processing Record 49 of Set 3 | carutapera
# Processing Record 0 of Set 4 | borazjan
# Processing Record 1 of Set 4 | margate
# Processing Record 2 of Set 4 | espargos
# City not found. Skipping...
# Processing Record 3 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 4 of Set 4 | shakiso
# Processing Record 5 of Set 4 | rokytne
# Processing Record 6 of Set 4 | talnakh
# Processing Record 7 of Set 4 | aasiaat
# Processing Record 8 of Set 4 | callao
# Processing Record 9 of Set 4 | zhob
# Processing Record 10 of Set 4 | vilyuchinsk
# Processing Record 11 of Set 4 | ostersund
# Processing Record 12 of Set 4 | kodiak
# Processing Record 13 of Set 4 | frontera
# Processing Record 14 of Set 4 | chifeng
# Processing Record 15 of Set 4 | rasinari
# Processing Record 16 of Set 4 | berdigestyakh
# Processing Record 17 of Set 4 | invercargill
# Processing Record 18 of Set 4 | soeng sang
# Processing Record 19 of Set 4 | verkhovazh'ye
# Processing Record 20 of Set 4 | port augusta
# Processing Record 21 of Set 4 | barra de santo antonio
# Processing Record 22 of Set 4 | san patricio
# Processing Record 23 of Set 4 | iron river
# Processing Record 24 of Set 4 | santa cruz
# Processing Record 25 of Set 4 | mount pleasant
# Processing Record 26 of Set 4 | puerto santa
# Processing Record 27 of Set 4 | port isabel
# Processing Record 28 of Set 4 | afaahiti
# Processing Record 29 of Set 4 | greymouth
# Processing Record 30 of Set 4 | north bend
# Processing Record 31 of Set 4 | prince george
# Processing Record 32 of Set 4 | mount gambier
# Processing Record 33 of Set 4 | fort bragg
# Processing Record 34 of Set 4 | el calafate
# Processing Record 35 of Set 4 | kayangel
# Processing Record 36 of Set 4 | bengkulu
# Processing Record 37 of Set 4 | queenstown
# Processing Record 38 of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 39 of Set 4 | tura
# Processing Record 40 of Set 4 | naze
# Processing Record 41 of Set 4 | tynda
# Processing Record 42 of Set 4 | christchurch
# Processing Record 43 of Set 4 | camaqua
# Processing Record 44 of Set 4 | nova xavantina
# Processing Record 45 of Set 4 | banjarmasin
# Processing Record 46 of Set 4 | hassi messaoud
# Processing Record 47 of Set 4 | arraial do cabo
# Processing Record 48 of Set 4 | fort mcmurray
# Processing Record 49 of Set 4 | smara
# Processing Record 0 of Set 5 | tazovsky
# Processing Record 1 of Set 5 | tougan
# Processing Record 2 of Set 5 | northam
# Processing Record 3 of Set 5 | uturoa
# Processing Record 4 of Set 5 | shanhaiguan
# Processing Record 5 of Set 5 | geraldton
# Processing Record 6 of Set 5 | bandar abbas
# Processing Record 7 of Set 5 | wailua homesteads
# Processing Record 8 of Set 5 | broken hill
# Processing Record 9 of Set 5 | bahia de kino
# Processing Record 10 of Set 5 | kodok
# City not found. Skipping...
# Processing Record 11 of Set 5 | mount isa
# Processing Record 12 of Set 5 | punaauia
# Processing Record 13 of Set 5 | joshimath
# Processing Record 14 of Set 5 | qurayyat
# Processing Record 15 of Set 5 | fuvahmulah
# City not found. Skipping...
# Processing Record 16 of Set 5 | altamira
# Processing Record 17 of Set 5 | loukhi
# Processing Record 18 of Set 5 | kardla
# Processing Record 19 of Set 5 | lospalos
# Processing Record 20 of Set 5 | port saint john's
# Processing Record 21 of Set 5 | vorgashor
# Processing Record 22 of Set 5 | gien
# Processing Record 23 of Set 5 | luderitz
# Processing Record 24 of Set 5 | saldanha
# Processing Record 25 of Set 5 | ascension
# Processing Record 26 of Set 5 | waddan
# Processing Record 27 of Set 5 | las heras
# Processing Record 28 of Set 5 | inari
# Processing Record 29 of Set 5 | minas de marcona
# Processing Record 30 of Set 5 | yashkul'
# Processing Record 31 of Set 5 | kpandae
# Processing Record 32 of Set 5 | mersing
# Processing Record 33 of Set 5 | green river
# Processing Record 34 of Set 5 | nemuro
# Processing Record 35 of Set 5 | dunedin
# Processing Record 36 of Set 5 | kununurra
# Processing Record 37 of Set 5 | san luis de la loma
# Processing Record 38 of Set 5 | susuman
# Processing Record 39 of Set 5 | salmon arm
# Processing Record 40 of Set 5 | utrik
# Processing Record 41 of Set 5 | valdivia
# Processing Record 42 of Set 5 | howrah
# Processing Record 43 of Set 5 | harstad
# Processing Record 44 of Set 5 | brisas de zicatela
# Processing Record 45 of Set 5 | strezhevoy
# Processing Record 46 of Set 5 | princeville
# Processing Record 47 of Set 5 | conduaga
# Processing Record 48 of Set 5 | selfoss
# Processing Record 49 of Set 5 | canutama
# Processing Record 0 of Set 6 | kavaratti
# Processing Record 1 of Set 6 | ust-nera
# Processing Record 2 of Set 6 | ziro
# Processing Record 3 of Set 6 | carnarvon
# Processing Record 4 of Set 6 | bardai
# Processing Record 5 of Set 6 | santo antonio do leverger
# Processing Record 6 of Set 6 | lenger
# Processing Record 7 of Set 6 | launceston
# Processing Record 8 of Set 6 | molde
# Processing Record 9 of Set 6 | muhlhausen
# Processing Record 10 of Set 6 | colonia
# Processing Record 11 of Set 6 | ziguinchor
# Processing Record 12 of Set 6 | kralendijk
# Processing Record 13 of Set 6 | kiruna
# Processing Record 14 of Set 6 | corner brook
# Processing Record 15 of Set 6 | saraqib
# Processing Record 16 of Set 6 | nuuk
# Processing Record 17 of Set 6 | gagliano del capo
# Processing Record 18 of Set 6 | porto novo
# Processing Record 19 of Set 6 | ta`u
# Processing Record 20 of Set 6 | la'ie
# Processing Record 21 of Set 6 | atafu village
# Processing Record 22 of Set 6 | coahuayana de hidalgo
# Processing Record 23 of Set 6 | tauranga
# Processing Record 24 of Set 6 | novyy urgal
# Processing Record 25 of Set 6 | lexington
# Processing Record 26 of Set 6 | inarajan village
# Processing Record 27 of Set 6 | constantia
# Processing Record 28 of Set 6 | viedma
# Processing Record 29 of Set 6 | mena
# Processing Record 30 of Set 6 | kapa'a
# Processing Record 31 of Set 6 | isangel
# Processing Record 32 of Set 6 | aykol
# City not found. Skipping...
# Processing Record 33 of Set 6 | constitucion
# Processing Record 34 of Set 6 | cabo san lucas
# Processing Record 35 of Set 6 | lerwick
# Processing Record 36 of Set 6 | santa terezinha
# Processing Record 37 of Set 6 | godda
# Processing Record 38 of Set 6 | nizhniy ingash
# Processing Record 39 of Set 6 | nova sintra
# Processing Record 40 of Set 6 | totness
# Processing Record 41 of Set 6 | komsomolets
# Processing Record 42 of Set 6 | bechar
# Processing Record 43 of Set 6 | maitum
# Processing Record 44 of Set 6 | bubaque
# Processing Record 45 of Set 6 | vilyuysk
# Processing Record 46 of Set 6 | chinde
# Processing Record 47 of Set 6 | rio grande
# Processing Record 48 of Set 6 | puerto armuelles
# Processing Record 49 of Set 6 | crane
# Processing Record 0 of Set 7 | saipan
# Processing Record 1 of Set 7 | lihue
# Processing Record 2 of Set 7 | st. john's
# Processing Record 3 of Set 7 | island harbour
# Processing Record 4 of Set 7 | mahina
# Processing Record 5 of Set 7 | tabas
# Processing Record 6 of Set 7 | la passe
# Processing Record 7 of Set 7 | dalandzadgad
# Processing Record 8 of Set 7 | smithers
# Processing Record 9 of Set 7 | miri
# Processing Record 10 of Set 7 | bridgewater
# Processing Record 11 of Set 7 | turaif
# Processing Record 12 of Set 7 | turabah
# Processing Record 13 of Set 7 | ouarzazat
# Processing Record 14 of Set 7 | ghadamis
# Processing Record 15 of Set 7 | nogliki
# Processing Record 16 of Set 7 | flying fish cove
# Processing Record 17 of Set 7 | ar ruways
# Processing Record 18 of Set 7 | panacan
# Processing Record 19 of Set 7 | tolanaro
# Processing Record 20 of Set 7 | caetite
# Processing Record 21 of Set 7 | yeniseysk
# Processing Record 22 of Set 7 | pariaman
# Processing Record 23 of Set 7 | valle de la pascua
# Processing Record 24 of Set 7 | diu
# Processing Record 25 of Set 7 | odienne
# Processing Record 26 of Set 7 | el granada
# Processing Record 27 of Set 7 | teguise
# Processing Record 28 of Set 7 | toga village
# City not found. Skipping...
# Processing Record 29 of Set 7 | cam ranh
# Processing Record 30 of Set 7 | kiunga
# Processing Record 31 of Set 7 | khorixas
# Processing Record 32 of Set 7 | cuiaba
# Processing Record 33 of Set 7 | chesterton
# Processing Record 34 of Set 7 | kingston
# Processing Record 35 of Set 7 | tazacorte
# Processing Record 36 of Set 7 | kawthoung
# City not found. Skipping...
# Processing Record 37 of Set 7 | codrington
# Processing Record 38 of Set 7 | kruisfontein
# Processing Record 39 of Set 7 | chapeco
# Processing Record 40 of Set 7 | kristiansund
# Processing Record 41 of Set 7 | yuzhno-kurilsk
# Processing Record 42 of Set 7 | usogorsk
# Processing Record 43 of Set 7 | vilhena
# Processing Record 44 of Set 7 | les avirons
# Processing Record 45 of Set 7 | lianjiang
# Processing Record 46 of Set 7 | 'ohonua
# City not found. Skipping...
# Processing Record 47 of Set 7 | lander
# Processing Record 48 of Set 7 | prince rupert
# Processing Record 49 of Set 7 | apolinario saravia
# Processing Record 0 of Set 8 | belmonte
# Processing Record 1 of Set 8 | iquique
# Processing Record 2 of Set 8 | taltal
# Processing Record 3 of Set 8 | greenville
# Processing Record 4 of Set 8 | san-pedro
# Processing Record 5 of Set 8 | auki
# Processing Record 6 of Set 8 | sisimiut
# Processing Record 7 of Set 8 | augusto correa
# Processing Record 8 of Set 8 | fauske
# Processing Record 9 of Set 8 | shiqian
# Processing Record 10 of Set 8 | kilindoni
# Processing Record 11 of Set 8 | new norfolk
# Processing Record 12 of Set 8 | 'ain el hadjel
# City not found. Skipping...
# Processing Record 13 of Set 8 | horta
# Processing Record 14 of Set 8 | xilin hot
# Processing Record 15 of Set 8 | labasa
# Processing Record 16 of Set 8 | el viejo
# Processing Record 17 of Set 8 | cargados carajos
# City not found. Skipping...
# Processing Record 18 of Set 8 | farafangana
# Processing Record 19 of Set 8 | alesund
# Processing Record 20 of Set 8 | trincomalee
# Processing Record 21 of Set 8 | fakenham
# Processing Record 22 of Set 8 | atar
# Processing Record 23 of Set 8 | hadibu
# Processing Record 24 of Set 8 | sault ste. marie
# Processing Record 25 of Set 8 | labytnangi
# Processing Record 26 of Set 8 | badger
# Processing Record 27 of Set 8 | champerico
# Processing Record 28 of Set 8 | garden city
# Processing Record 29 of Set 8 | vadso
# Processing Record 30 of Set 8 | holualoa
# Processing Record 31 of Set 8 | port hedland
# Processing Record 32 of Set 8 | acajutla
# Processing Record 33 of Set 8 | ca mau
# Processing Record 34 of Set 8 | thenia
# Processing Record 35 of Set 8 | la sarre
# Processing Record 36 of Set 8 | hayma'
# City not found. Skipping...
# Processing Record 37 of Set 8 | kidal
# Processing Record 38 of Set 8 | remire-montjoly
# Processing Record 39 of Set 8 | okahao
# Processing Record 40 of Set 8 | cole harbour
# Processing Record 41 of Set 8 | grand falls-windsor
# Processing Record 42 of Set 8 | sandefjord
# Processing Record 43 of Set 8 | kuanda
# Processing Record 44 of Set 8 | beyneu
# Processing Record 45 of Set 8 | bodaybo
# Processing Record 46 of Set 8 | tyukhtet
# Processing Record 47 of Set 8 | castillos
# Processing Record 48 of Set 8 | puerto lempira
# Processing Record 49 of Set 8 | mogocha
# Processing Record 0 of Set 9 | annau
# Processing Record 1 of Set 9 | mejit
# Processing Record 2 of Set 9 | arish
# Processing Record 3 of Set 9 | karamay
# City not found. Skipping...
# Processing Record 4 of Set 9 | tondano
# Processing Record 5 of Set 9 | akrehamn
# Processing Record 6 of Set 9 | dobryanka
# Processing Record 7 of Set 9 | kastel novi
# City not found. Skipping...
# Processing Record 8 of Set 9 | rongelap
# Processing Record 9 of Set 9 | yarmolyntsi
# Processing Record 10 of Set 9 | hailar
# Processing Record 11 of Set 9 | chashniki
# Processing Record 12 of Set 9 | concepcion del uruguay
# Processing Record 13 of Set 9 | fortaleza
# Processing Record 14 of Set 9 | chonchi
# Processing Record 15 of Set 9 | benguela
# Processing Record 16 of Set 9 | vidalia
# Processing Record 17 of Set 9 | myadzyel
# Processing Record 18 of Set 9 | dabeiba
# Processing Record 19 of Set 9 | touros
# Processing Record 20 of Set 9 | dwarka
# Processing Record 21 of Set 9 | praia da vitoria
# Processing Record 22 of Set 9 | labuan
# Processing Record 23 of Set 9 | zakynthos
# Processing Record 24 of Set 9 | redencao
# Processing Record 25 of Set 9 | kharkhorin
# Processing Record 26 of Set 9 | islamorada
# Processing Record 27 of Set 9 | sandnessjoen
# Processing Record 28 of Set 9 | jember
# Processing Record 29 of Set 9 | dakhla
# Processing Record 30 of Set 9 | hoemul-li
# Processing Record 31 of Set 9 | nishinoomote
# Processing Record 32 of Set 9 | kone
# Processing Record 33 of Set 9 | kalmunai
# Processing Record 34 of Set 9 | elverum
# Processing Record 35 of Set 9 | enriquillo
# Processing Record 36 of Set 9 | lively
# Processing Record 37 of Set 9 | wenchang
# Processing Record 38 of Set 9 | kolonia
# Processing Record 39 of Set 9 | rawson
# Processing Record 40 of Set 9 | concepcion
# Processing Record 41 of Set 9 | laguna
# Processing Record 42 of Set 9 | lompoc
# Processing Record 43 of Set 9 | mount pearl
# Processing Record 44 of Set 9 | ranau
# Processing Record 45 of Set 9 | lulea
# Processing Record 46 of Set 9 | nantucket
# Processing Record 47 of Set 9 | nevada
# Processing Record 48 of Set 9 | port blair
# Processing Record 49 of Set 9 | bonthe
# Processing Record 0 of Set 10 | harar
# Processing Record 1 of Set 10 | vyazemskiy
# Processing Record 2 of Set 10 | alofi
# Processing Record 3 of Set 10 | usinsk
# Processing Record 4 of Set 10 | kunnumma
# City not found. Skipping...
# Processing Record 5 of Set 10 | mahibadhoo
# Processing Record 6 of Set 10 | errachidia
# Processing Record 7 of Set 10 | forster
# Processing Record 8 of Set 10 | turbat
# Processing Record 9 of Set 10 | pante makasar
# City not found. Skipping...
# Processing Record 10 of Set 10 | al kiremit al 'arakiyyin
# City not found. Skipping...
# Processing Record 11 of Set 10 | nokha
# Processing Record 12 of Set 10 | amble
# Processing Record 13 of Set 10 | kalyazin
# Processing Record 14 of Set 10 | am djarass
# City not found. Skipping...
# Processing Record 15 of Set 10 | dabakala
# Processing Record 16 of Set 10 | cambria
# Processing Record 17 of Set 10 | rawala kot
# Processing Record 18 of Set 10 | axum
# Processing Record 19 of Set 10 | bontang
# Processing Record 20 of Set 10 | kushiro
# Processing Record 21 of Set 10 | aripuana
# Processing Record 22 of Set 10 | akureyri
# Processing Record 23 of Set 10 | daoukro
# Processing Record 24 of Set 10 | soygaon
# Processing Record 25 of Set 10 | conde
# Processing Record 26 of Set 10 | anatuya
# Processing Record 27 of Set 10 | cannonvale
# Processing Record 28 of Set 10 | dalnegorsk
# Processing Record 29 of Set 10 | thanh hoa
# Processing Record 30 of Set 10 | marsh harbour
# Processing Record 31 of Set 10 | funafuti
# Processing Record 32 of Set 10 | as sulaymaniyah
# Processing Record 33 of Set 10 | karatuzskoye
# Processing Record 34 of Set 10 | antonio enes
# Processing Record 35 of Set 10 | derbent
# Processing Record 36 of Set 10 | pandan
# Processing Record 37 of Set 10 | tamanrasset
# Processing Record 38 of Set 10 | concepcion del oro
# Processing Record 39 of Set 10 | cromer
# Processing Record 40 of Set 10 | nacozari de garcia
# Processing Record 41 of Set 10 | katol
# Processing Record 42 of Set 10 | zeya
# Processing Record 43 of Set 10 | sao lourenco do oeste
# Processing Record 44 of Set 10 | kailua-kona
# Processing Record 45 of Set 10 | vurnary
# Processing Record 46 of Set 10 | namsos
# Processing Record 47 of Set 10 | verkhnevilyuysk
# Processing Record 48 of Set 10 | pitanga
# Processing Record 49 of Set 10 | tegueste
# Processing Record 0 of Set 11 | hilo
# Processing Record 1 of Set 11 | kangding
# Processing Record 2 of Set 11 | sagua de tanamo
# Processing Record 3 of Set 11 | soledar
# Processing Record 4 of Set 11 | kudahuvadhoo
# Processing Record 5 of Set 11 | newman
# Processing Record 6 of Set 11 | turinskaya sloboda
# Processing Record 7 of Set 11 | port douglas
# Processing Record 8 of Set 11 | sergeyevka
# Processing Record 9 of Set 11 | al ghayzah
# Processing Record 10 of Set 11 | kavieng
# Processing Record 11 of Set 11 | hammerfest
# Processing Record 12 of Set 11 | saint-philippe
# Processing Record 13 of Set 11 | belyy yar
# Processing Record 14 of Set 11 | tulle
# Processing Record 15 of Set 11 | presidente epitacio
# Processing Record 16 of Set 11 | barroquinha
# Processing Record 17 of Set 11 | meadow lake
# Processing Record 18 of Set 11 | tulum
# Processing Record 19 of Set 11 | poquoson
# Processing Record 20 of Set 11 | egilsstadir
# Processing Record 21 of Set 11 | kourou
# Processing Record 22 of Set 11 | east london
# Processing Record 23 of Set 11 | san rafael
# Processing Record 24 of Set 11 | taoudenni
# Processing Record 25 of Set 11 | laurentides
# Processing Record 26 of Set 11 | jincheng
# Processing Record 27 of Set 11 | ujae
# Processing Record 28 of Set 11 | chokwe
# Processing Record 29 of Set 11 | salalah
# Processing Record 30 of Set 11 | polyarnyy
# Processing Record 31 of Set 11 | cooper's town
# Processing Record 32 of Set 11 | twon-brass
# Processing Record 33 of Set 11 | sejong
# Processing Record 34 of Set 11 | bor
# Processing Record 35 of Set 11 | mutuali
# Processing Record 36 of Set 11 | parun
# Processing Record 37 of Set 11 | arauca
# Processing Record 38 of Set 11 | santa ana de yacuma
# Processing Record 39 of Set 11 | mana
# Processing Record 40 of Set 11 | benghazi
# Processing Record 41 of Set 11 | aral
# Processing Record 42 of Set 11 | nar'yan-mar
# Processing Record 43 of Set 11 | halifax
# Processing Record 44 of Set 11 | dickinson
# Processing Record 45 of Set 11 | calliope
# Processing Record 46 of Set 11 | armacao de buzios
# Processing Record 47 of Set 11 | jilib
# Processing Record 48 of Set 11 | balkanabat
# Processing Record 49 of Set 11 | okakarara
# Processing Record 0 of Set 12 | popondetta
# Processing Record 1 of Set 12 | gustrow
# Processing Record 2 of Set 12 | san andres
# Processing Record 3 of Set 12 | imbituba
# Processing Record 4 of Set 12 | trondheim
# Processing Record 5 of Set 12 | sunan
# Processing Record 6 of Set 12 | paragominas
# Processing Record 7 of Set 12 | fisterra
# Processing Record 8 of Set 12 | phalodi
# Processing Record 9 of Set 12 | cooma
# Processing Record 10 of Set 12 | vingt cinq
# City not found. Skipping...
# Processing Record 11 of Set 12 | nouadhibou
# Processing Record 12 of Set 12 | vila franca do campo
# Processing Record 13 of Set 12 | mayna
# Processing Record 14 of Set 12 | salinopolis
# Processing Record 15 of Set 12 | sao felix do xingu
# Processing Record 16 of Set 12 | chibougamau
# Processing Record 17 of Set 12 | mahebourg
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          542
# Lat           542
# Lng           542
# Max Temp      542
# Humidity      542
# Cloudiness    542
# Wind Speed    542
# Country       542
# Date          542
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  port-aux-francais -49.3500   70.2167    274.80        72          45
# 1         whitehorse  60.7161 -135.0538    289.58        82          40
# 2          grytviken -54.2811  -36.5092    271.30        91          31
# 3             recani  31.2846   -4.2688    304.42        23          43
# 4    lazaro cardenas  17.9583 -102.2000    302.04        84          25
#
#    Wind Speed Country        Date
# 0        6.00      TF  1691551410
# 1        1.03      CA  1691551249
# 2        4.60      GS  1691551148
# 3        3.16      MA  1691551412
# 4        3.15      MX  1691550867

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167    274.80        72          45
# 1               whitehorse  60.7161 -135.0538    289.58        82          40
# 2                grytviken -54.2811  -36.5092    271.30        91          31
# 3                   recani  31.2846   -4.2688    304.42        23          43
# 4          lazaro cardenas  17.9583 -102.2000    302.04        84          25
#
#          Wind Speed Country        Date
# City_ID
# 0              6.00      TF  1691551410
# 1              1.03      CA  1691551249
# 2              4.60      GS  1691551148
# 3              3.16      MA  1691551412
# 4              3.15      MX  1691550867

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], alpha=.8, edgecolors="k")
# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(True) 

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"])
# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.tight_layout()
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]) > 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1             whitehorse  60.7161 -135.0538    289.58        82          40
# 3                 recani  31.2846   -4.2688    304.42        23          43
# 4        lazaro cardenas  17.9583 -102.2000    302.04        84          25
# 10              mantsala  60.6609   25.2838    286.07        94           0
# 11              hamilton  39.1834  -84.5333    295.98        82           0
#
#          Wind Speed Country        Date
# City_ID
# 1              1.03      CA  1691551249
# 3              3.16      MA  1691551412
# 4              3.15      MX  1691550867
# 10             1.98      FI  1691551414
# 11             2.06      US  1691551044

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]) < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167    274.80        72          45
# 2                grytviken -54.2811  -36.5092    271.30        91          31
# 5                 hermanus -34.4187   19.2345    283.68        84           0
# 6            blackmans bay -43.0167  147.3167    287.22        55         100
# 7             saint-pierre -21.3393   55.4781    291.97        63           0
#
#          Wind Speed Country        Date
# City_ID
# 0              6.00      TF  1691551410
# 2              4.60      GS  1691551148
# 5              6.24      ZA  1691551171
# 6              3.45      AU  1691551102
# 7              3.09      RE  1691551250

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
reg_val = x_values * slope + intercept


plt.scatter(x_values, y_values)
plt.plot(x_values, reg_val, "-r")
plt.annotate(line_eq,(0,-20),fontsize=20,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
# Out:
# Text(0, 0.5, 'Max Temp')

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
reg_values = x_values * slope + intercept

plt.scatter(x_values, y_values)

# %% [markdown]
# **Discussion about the linear relationship:** Negative relationship between temp and lat.
# Positive relation on the southern hemisphere

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

plt.scatter(x_values, y_values)

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

plt.scatter(x_values, y_values)

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.scatter(x_values, y_values)

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

plt.scatter(x_values, y_values)

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_vals = x_values * slope + intercept

plt.scatter(x_values, y_values)

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_vals = x_values * slope + intercept

plt.scatter(x_values, y_values)

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
